# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
import tensorflow as tf

# %%
data = pd.read_csv("data\mergedata.csv")
data.head()
# Out:
#   Learning Path ID      Learning Path  \
# 0                7  Android Developer
# 1                7  Android Developer
# 2                7  Android Developer
# 3                7  Android Developer
# 4                7  Android Developer
#
#                                Learning Path Summary  Course ID  \
# 0  Kurikulum didesain dengan persetujuan dari Tim...         80
# 1  Kurikulum didesain dengan persetujuan dari Tim...         80
# 2  Kurikulum didesain dengan persetujuan dari Tim...         80
# 3  Kurikulum didesain dengan persetujuan dari Tim...         80
# 4  Kurikulum didesain dengan persetujuan dari Tim...         80
#
#                        Course Name_x  \
# 0  Memulai Pemrograman dengan Kotlin
# 1  Memulai Pemrograman dengan Kotlin
# 2  Memulai Pemrograman dengan Kotlin
# 3  Memulai Pemrograman dengan Kotlin
# 4  Memulai Pemrograman dengan Kotlin
#
#                                       Course Summary     Price  Level  \
# 0  Pelajari dasar bahasa pemrograman, functional ...  Berbayar  Dasar
# 1  Pelajari dasar bahasa pemrograman, functional ...  Berbayar  Dasar
# 2  Pelajari dasar bahasa pemrograman, functional ...  Berbayar  Dasar
# 3  Pelajari dasar bahasa pemrograman, functional ...  Berbayar  Dasar
# 4  Pelajari dasar bahasa pemrograman, functional ...  Berbayar  Dasar
#
#    Total Jam Belajar Rating  Jumlah Enrollment  Jumlah Modul/Tutorial  \
# 0                 50   4.84              67917                    132
# 1                 50   4.84              67917                    132
# 2                 50   4.84              67917                    132
# 3                 50   4.84              67917                    132
# 4                 50   4.84              67917                    132
#
#                   Judul Modul/Tutorial
# 0                        Latihan Ujian
# 1                    Pengenalan Kotlin
# 2  Kotlin Sebagai Bahasa Multiparadigm
# 3  Kotlin Sebagai Bahasa Multiplatform
# 4    Kotlin untuk Aplikasi Server-side

# %%
data.shape
# Out:
# (6104, 13)

# %%
data.info
# Out:
# <bound method DataFrame.info of      Learning Path ID      Learning Path  \
# 0                   7  Android Developer
# 1                   7  Android Developer
# 2                   7  Android Developer
# 3                   7  Android Developer
# 4                   7  Android Developer
# ...               ...                ...
# 6099              NaN                NaN
# 6100              NaN                NaN
# 6101              NaN                NaN
# 6102              NaN                NaN
# 6103              NaN                NaN
#
#                                   Learning Path Summary  Course ID  \
# 0     Kurikulum didesain dengan persetujuan dari Tim...         80
# 1     Kurikulum didesain dengan persetujuan dari Tim...         80
# 2     Kurikulum didesain dengan persetujuan dari Tim...         80
# 3     Kurikulum didesain dengan persetujuan dari Tim...         80
# 4     Kurikulum didesain dengan persetujuan dari Tim...         80
# ...                                                 ...        ...
# 6099                                                NaN        703
# 6100                                                NaN        703
# 6101                                                NaN        703
# 6102                                                NaN        703
# 6103                                                NaN        703
#
#                                         Course Name_x  \
# 0                   Memulai Pemrograman dengan Kotlin
# 1                   Memulai Pemrograman dengan Kotlin
# 2                   Memulai Pemrograman dengan Kotlin
# 3                   Memulai Pemrograman dengan Kotlin
# 4                   Memulai Pemrograman dengan Kotlin
# ...                                               ...
# 6099  Dev Certification for Android (DCA) Preparation
# 6100  Dev Certification for Android (DCA) Preparation
# 6101  Dev Certification for Android (DCA) Preparation
# 6102  Dev Certification for Android (DCA) Preparation
# 6103  Dev Certification for Android (DCA) Preparation
#
#                                          Course Summary     Price  \
# 0     Pelajari dasar bahasa pemrograman, functional ...  Berbayar
# 1     Pelajari dasar bahasa pemrograman, functional ...  Berbayar
# 2     Pelajari dasar bahasa pemrograman, functional ...  Berbayar
# 3     Pelajari dasar bahasa pemrograman, functional ...  Berbayar
# 4     Pelajari dasar bahasa pemrograman, functional ...  Berbayar
# ...                                                 ...       ...
# 6099  Preparation course for taking the Dev Certific...  Berbayar
# 6100  Preparation course for taking the Dev Certific...  Berbayar
# 6101  Preparation course for taking the Dev Certific...  Berbayar
# 6102  Preparation course for taking the Dev Certific...  Berbayar
# 6103  Preparation course for taking the Dev Certific...  Berbayar
#
#                        Level  Total Jam Belajar Rating  Jumlah Enrollment  \
# 0                      Dasar                 50   4.84              67917
# 1                      Dasar                 50   4.84              67917
# 2                      Dasar                 50   4.84              67917
# 3                      Dasar                 50   4.84              67917
# 4                      Dasar                 50   4.84              67917
# ...                      ...                ...    ...                ...
# 6099  Kompetensi Sertifikasi                 40    NaN                737
# 6100  Kompetensi Sertifikasi                 40    NaN                737
# 6101  Kompetensi Sertifikasi                 40    NaN                737
# 6102  Kompetensi Sertifikasi                 40    NaN                737
# 6103  Kompetensi Sertifikasi                 40    NaN                737
#
#       Jumlah Modul/Tutorial                    Judul Modul/Tutorial
# 0                       132                           Latihan Ujian
# 1                       132                       Pengenalan Kotlin
# 2                       132     Kotlin Sebagai Bahasa Multiparadigm
# 3                       132     Kotlin Sebagai Bahasa Multiplatform
# 4                       132       Kotlin untuk Aplikasi Server-side
# ...                     ...                                     ...
# 6099                     14  Course Scheduler App Submit and Review
# 6100                     14                        Project Overview
# 6101                     14                         Code Submission
# 6102                     14                          Exit Interview
# 6103                     14     Habit Tracker App Submit and Review
#
# [6104 rows x 13 columns]>

# %%
data.head()
# Out:
#   Learning Path ID      Learning Path  \
# 0                7  Android Developer
# 1                7  Android Developer
# 2                7  Android Developer
# 3                7  Android Developer
# 4                7  Android Developer
#
#                                Learning Path Summary  Course ID  \
# 0  Kurikulum didesain dengan persetujuan dari Tim...         80
# 1  Kurikulum didesain dengan persetujuan dari Tim...         80
# 2  Kurikulum didesain dengan persetujuan dari Tim...         80
# 3  Kurikulum didesain dengan persetujuan dari Tim...         80
# 4  Kurikulum didesain dengan persetujuan dari Tim...         80
#
#                        Course Name_x  \
# 0  Memulai Pemrograman dengan Kotlin
# 1  Memulai Pemrograman dengan Kotlin
# 2  Memulai Pemrograman dengan Kotlin
# 3  Memulai Pemrograman dengan Kotlin
# 4  Memulai Pemrograman dengan Kotlin
#
#                                       Course Summary     Price  Level  \
# 0  Pelajari dasar bahasa pemrograman, functional ...  Berbayar  Dasar
# 1  Pelajari dasar bahasa pemrograman, functional ...  Berbayar  Dasar
# 2  Pelajari dasar bahasa pemrograman, functional ...  Berbayar  Dasar
# 3  Pelajari dasar bahasa pemrograman, functional ...  Berbayar  Dasar
# 4  Pelajari dasar bahasa pemrograman, functional ...  Berbayar  Dasar
#
#    Total Jam Belajar Rating  Jumlah Enrollment  Jumlah Modul/Tutorial  \
# 0                 50   4.84              67917                    132
# 1                 50   4.84              67917                    132
# 2                 50   4.84              67917                    132
# 3                 50   4.84              67917                    132
# 4                 50   4.84              67917                    132
#
#                   Judul Modul/Tutorial
# 0                        Latihan Ujian
# 1                    Pengenalan Kotlin
# 2  Kotlin Sebagai Bahasa Multiparadigm
# 3  Kotlin Sebagai Bahasa Multiplatform
# 4    Kotlin untuk Aplikasi Server-side

# %%
null_counts = data.isnull().sum()
print(null_counts)
# Out:
# Learning Path ID         5235
# Learning Path            5286
# Learning Path Summary    5286
# Course ID                   0
# Course Name_x               0
# Course Summary              0
# Price                       0
# Level                       0
# Total Jam Belajar           0
# Rating                     48
# Jumlah Enrollment           0
# Jumlah Modul/Tutorial       0
# Judul Modul/Tutorial        0
# dtype: int64

# %%
data['Learning Path'] = data['Learning Path'].ffill()
data['Learning Path Summary'] = data['Learning Path Summary'].ffill()

# %%
data.to_csv('updatemergedata.csv', index=False)
